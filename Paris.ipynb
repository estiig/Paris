# %%
import pandas as pd
import requests
import numpy as np

df = pd.read_csv('./paris_cp.csv')
# Dataframe with 3 columns
# df = pd.DataFrame(res, columns = ["PostalCode", "Borough", "Neighborhood"])
# df.head()

df.head()
# Out:
#    Code_commune_INSEE Nom_commune  Code_postal  Ligne_5  \
# 0               75106    PARIS 06        75006      NaN
# 1               75112    PARIS 12        75012      NaN
# 2               75113    PARIS 13        75013      NaN
# 3               75118    PARIS 18        75018      NaN
# 4               67180    HAGUENAU        67500      NaN
#
#   Libellé_d_acheminement              coordonnees_gps
# 0                  PARIS  48.8489680919,2.33267089859
# 1                  PARIS  48.8351562307,2.41980703497
# 2                  PARIS  48.8287176845,2.36246822852
# 3                  PARIS  48.8927350746,2.34871193387
# 4               HAGUENAU  48.8417047695,7.83010404968

# %%
# !conda install -c conda-forge folium=0.5.0 --yes
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.8.5
#   latest version: 4.9.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     altair-4.1.0               |             py_1         614 KB  conda-forge
#     branca-0.4.1               |             py_0          26 KB  conda-forge
#     brotlipy-0.7.0             |py36he6145b8_1001         347 KB  conda-forge
#     certifi-2020.6.20          |   py36h9880bd3_2         151 KB  conda-forge
#     chardet-3.0.4              |py36h9880bd3_1008         194 KB  conda-forge
#     cryptography-3.2           |   py36h5d711a5_0         622 KB  conda-forge
#     entrypoints-0.3            |py36h9f0ad1d_1002          13 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     importlib_metadata-2.0.0   |                1           3 KB  conda-forge
#     jsonschema-3.2.0           |             py_2          45 KB  conda-forge
#     markupsafe-1.1.1           |   py36he6145b8_2          27 KB  conda-forge
#     pandas-1.1.3               |   py36h66e3816_2        10.5 MB  conda-forge
#     pyrsistent-0.17.3          |   py36h8c4c3a4_1          89 KB  conda-forge
#     pysocks-1.7.1              |   py36h9880bd3_2          27 KB  conda-forge
#     toolz-0.11.1               |             py_0          46 KB  conda-forge
#     urllib3-1.25.11            |             py_0          93 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        12.8 MB
#
# The following NEW packages will be INSTALLED:
#
#   altair             conda-forge/noarch::altair-4.1.0-py_1
#   attrs              conda-forge/noarch::attrs-20.2.0-pyh9f0ad1d_0
#   branca             conda-forge/noarch::branca-0.4.1-py_0
#   brotlipy           conda-forge/linux-64::brotlipy-0.7.0-py36he6145b8_1001
#   chardet            conda-forge/linux-64::chardet-3.0.4-py36h9880bd3_1008
#   cryptography       conda-forge/linux-64::cryptography-3.2-py36h5d711a5_0
#   entrypoints        conda-forge/linux-64::entrypoints-0.3-py36h9f0ad1d_1002
#   folium             conda-forge/noarch::folium-0.5.0-py_0
#   idna               conda-forge/noarch::idna-2.10-pyh9f0ad1d_0
#   importlib_metadata conda-forge/noarch::importlib_metadata-2.0.0-1
#   jinja2             conda-forge/noarch::jinja2-2.11.2-pyh9f0ad1d_0
#   jsonschema         conda-forge/noarch::jsonschema-3.2.0-py_2
#   markupsafe         conda-forge/linux-64::markupsafe-1.1.1-py36he6145b8_2
#   pandas             conda-forge/linux-64::pandas-1.1.3-py36h66e3816_2
#   pyopenssl          conda-forge/noarch::pyopenssl-19.1.0-py_1
#   pyrsistent         conda-forge/linux-64::pyrsistent-0.17.3-py36h8c4c3a4_1
#   pysocks            conda-forge/linux-64::pysocks-1.7.1-py36h9880bd3_2
#   pytz               conda-forge/noarch::pytz-2020.1-pyh9f0ad1d_0
#   requests           conda-forge/noarch::requests-2.24.0-pyh9f0ad1d_0
#   toolz              conda-forge/noarch::toolz-0.11.1-py_0
#   urllib3            conda-forge/noarch::urllib3-1.25.11-py_0
#   vincent            conda-forge/noarch::vincent-0.4.4-py_1
#
# The following packages will be UPDATED:
#
#   certifi                          2020.6.20-py36h9f0ad1d_0 --> 2020.6.20-py36h9880bd3_2
#
#
#
# Downloading and Extracting Packages
# markupsafe-1.1.1     | 27 KB     | ##################################### | 100%
# certifi-2020.6.20    | 151 KB    | ##################################### | 100%
# pyrsistent-0.17.3    | 89 KB     | ##################################### | 100%
# pandas-1.1.3         | 10.5 MB   | ##################################### | 100%
# importlib_metadata-2 | 3 KB      | ##################################### | 100%
# jsonschema-3.2.0     | 45 KB     | ##################################### | 100%
# entrypoints-0.3      | 13 KB     | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# pysocks-1.7.1        | 27 KB     | ##################################### | 100%
# brotlipy-0.7.0       | 347 KB    | ##################################### | 100%
# chardet-3.0.4        | 194 KB    | ##################################### | 100%
# urllib3-1.25.11      | 93 KB     | ##################################### | 100%
# branca-0.4.1         | 26 KB     | ##################################### | 100%
# cryptography-3.2     | 622 KB    | ##################################### | 100%
# altair-4.1.0         | 614 KB    | ##################################### | 100%
# toolz-0.11.1         | 46 KB     | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
import folium # map rendering library

# %%
pip install geopy
# Out:
# Collecting geopy
#   Downloading https://files.pythonhosted.org/packages/07/e1/9c72de674d5c2b8fcb0738a5ceeb5424941fefa080bfe4e240d0bacb5a38/geopy-2.0.0-py3-none-any.whl (111kB)
#      |████████████████████████████████| 112kB 10.5MB/s eta 0:00:01
# Collecting geographiclib<2,>=1.49 (from geopy)
#   Downloading https://files.pythonhosted.org/packages/8b/62/26ec95a98ba64299163199e95ad1b0e34ad3f4e176e221c40245f211e425/geographiclib-1.50-py3-none-any.whl
# Installing collected packages: geographiclib, geopy
# Successfully installed geographiclib-1.50 geopy-2.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from geopy.geocoders import Nominatim

# %%
df.dtypes
# Out:
# Code_commune_INSEE          int64
# Nom_commune                object
# Code_postal                 int64
# Ligne_5                   float64
# Libellé_d_acheminement     object
# coordonnees_gps           float64
# latitude                  float64
# longitude                 float64
# dtype: object

# %%
#df["coordonnees_gps"] = df["coordonnees_gps"].str.split(",").tolist(),
                               #  columns = ["latitude", "longitude"])
#data = split_data.to_list()
#names = ["latitude", "longitude"]
#new_df = pd.DataFrame(data, columns=names)
#df = pd.DataFrame(df.row.str.split(',',1).tolist(),
  #                               columns = ["latitude", "longitude"])
df[["latitude", "longitude"]] = df.coordonnees_gps.str.split(",",expand=True,)

df
# Out:
#     Code_commune_INSEE           Nom_commune  Code_postal  Ligne_5  \
# 0                75106              PARIS 06        75006      NaN
# 1                75112              PARIS 12        75012      NaN
# 2                75113              PARIS 13        75013      NaN
# 3                75118              PARIS 18        75018      NaN
# 4                67180              HAGUENAU        67500      NaN
# 5                67331  NIEDERSCHAEFFOLSHEIM        67500      NaN
# 6                75102              PARIS 02        75002      NaN
# 7                75103              PARIS 03        75003      NaN
# 8                75108              PARIS 08        75008      NaN
# 9                75114              PARIS 14        75014      NaN
# 10               75116              PARIS 16        75016      NaN
# 11               75117              PARIS 17        75017      NaN
# 12               75119              PARIS 19        75019      NaN
# 13               75104              PARIS 04        75004      NaN
# 14               75107              PARIS 07        75007      NaN
# 15               75111              PARIS 11        75011      NaN
# 16               75115              PARIS 15        75015      NaN
# 17               75120              PARIS 20        75020      NaN
# 18               75101              PARIS 01        75001      NaN
# 19               75105              PARIS 05        75005      NaN
# 20               75109              PARIS 09        75009      NaN
# 21               75110              PARIS 10        75010      NaN
#
#    Libellé_d_acheminement              coordonnees_gps       latitude  \
# 0                   PARIS  48.8489680919,2.33267089859  48.8489680919
# 1                   PARIS  48.8351562307,2.41980703497  48.8351562307
# 2                   PARIS  48.8287176845,2.36246822852  48.8287176845
# 3                   PARIS  48.8927350746,2.34871193387  48.8927350746
# 4                HAGUENAU  48.8417047695,7.83010404968  48.8417047695
# 5    NIEDERSCHAEFFOLSHEIM  48.7725031726,7.74386109493  48.7725031726
# 6                   PARIS  48.8679033789,2.34410716666  48.8679033789
# 7                   PARIS  48.8630541318,2.35936105897  48.8630541318
# 8                   PARIS  48.8725272666,2.31258256042  48.8725272666
# 9                   PARIS  48.8289932116,2.32710088326  48.8289932116
# 10                  PARIS   48.8603987604,2.2620995594  48.8603987604
# 11                  PARIS  48.8873371665,2.30748555949  48.8873371665
# 12                  PARIS   48.886868623,2.38469432787   48.886868623
# 13                  PARIS   48.854228282,2.35736193814   48.854228282
# 14                  PARIS  48.8560825982,2.31243868773  48.8560825982
# 15                  PARIS  48.8594154976,2.37874106024  48.8594154976
# 16                  PARIS  48.8401554186,2.29355937244  48.8401554186
# 17                  PARIS  48.8631867774,2.40081982673  48.8631867774
# 18                  PARIS  48.8626304852,2.33629344655  48.8626304852
# 19                  PARIS  48.8445086596,2.34985938556  48.8445086596
# 20                  PARIS  48.8768961624,2.33746024139  48.8768961624
# 21                  PARIS  48.8760285569,2.36111290456  48.8760285569
#
#         longitude
# 0   2.33267089859
# 1   2.41980703497
# 2   2.36246822852
# 3   2.34871193387
# 4   7.83010404968
# 5   7.74386109493
# 6   2.34410716666
# 7   2.35936105897
# 8   2.31258256042
# 9   2.32710088326
# 10   2.2620995594
# 11  2.30748555949
# 12  2.38469432787
# 13  2.35736193814
# 14  2.31243868773
# 15  2.37874106024
# 16  2.29355937244
# 17  2.40081982673
# 18  2.33629344655
# 19  2.34985938556
# 20  2.33746024139
# 21  2.36111290456

# %%
pip install geopy
# Out:
# Requirement already satisfied: geopy in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (2.0.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from geopy) (1.50)
# Note: you may need to restart the kernel to use updated packages.

# %%
from geopy.geocoders import Nominatim

# %%
# !conda install -c conda-forge folium=0.5.0 --yes
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.8.5
#   latest version: 4.9.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# # All requested packages already installed.

# %%
#!conda install -c conda-forge folium=0.5.0 --yes 
import folium # map rendering library

# %%
df["latitude"] = df.latitude.astype(float)

# %%
df["longitude"] = df.longitude.astype(float)

# %%
df["coordonnees_gps"] = df.latitude.astype(float)

# %%
# create map of Toronto using latitude and longitude values
geolocator = Nominatim(user_agent="Paris_explorer")
address = "Paris"
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
latlng = (48.85837, 2.2944813)
map_paris = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
locations = df[['latitude', 'longitude']]
locationlist = locations.values.tolist()
len(locationlist)
map = folium.Map(location=latlng, zoom_start=12)
for point in range(0, len(locationlist)):
    label = '{}, {}'.format(Code_postal, Nom_commune)
    label = folium.Popup(label, parse_html=True)
    folium.Marker(locationlist[point], popup=df['Nom_commune'][point]).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
len(df)-1
# Out:
# 21

# %%
locationlist[1]
# Out:
# [48.8351562307, 48.8351562307]

# %%
df.head()
# Out:
#    Code_commune_INSEE Nom_commune  Code_postal  Ligne_5  \
# 0               75106    PARIS 06        75006      NaN
# 1               75112    PARIS 12        75012      NaN
# 2               75113    PARIS 13        75013      NaN
# 3               75118    PARIS 18        75018      NaN
# 4               67180    HAGUENAU        67500      NaN
#
#   Libellé_d_acheminement  coordonnees_gps   latitude  longitude
# 0                  PARIS        48.848968  48.848968  48.848968
# 1                  PARIS        48.835156  48.835156  48.835156
# 2                  PARIS        48.828718  48.828718  48.828718
# 3                  PARIS        48.892735  48.892735  48.892735
# 4               HAGUENAU        48.841705  48.841705  48.841705
